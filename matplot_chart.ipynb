# %% [markdown]
# <a href="https://colab.research.google.com/github/RokonUZ/DS/blob/main/matplot_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
bahadur=[6,54,15,9,5,4,3,2]
balubari=[8,60,10,7,4,2,5,2]

#plt.pie(balubari,explode=[0.2,0,0,0.2,0,0.2,0,0],labels=['cloth','Food waste','Plastic','Paper','Glass','Metal','Wood','Others'],autopct='%2.1f%%')

# %%
plt.scatter(bahadur,balubari)
plt.title("this is title")
# Out:
# Text(0.5, 1.0, 'this is title')

# %%
plt.plot(bahadur,balubari,'g',lineWidth=5)
plt.title("this is title")
# Out:
# Text(0.5, 1.0, 'this is title')

# %%
plt.bar(bahadur,balubari,label="bar chart",width=5)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.pie(balubari,explode=[0,0,0.2,0,0,0.3,0,0],labels=['cloth','Food waste','Plastic','Paper','Glass','Metal','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5867b5ff10>,
# ...
#  [Text(1.0640243508090608, 0.2790200367094752, 'cloth'),
#   Text(-0.8375905603371301, 0.7130512276366493, 'Food waste'),
#   Text(-0.041667000568498425, -1.2993320826731036, 'Plastic'),
#   Text(0.5397893644343169, -0.9584505423043989, 'Paper'),
#   Text(0.8375906020625498, -0.7130511786235934, 'Glass'),
#   Text(1.2198462291736907, -0.6870044957427338, 'Metal'),
#   Text(1.0545346594207845, -0.31298027426707015, 'Wood'),
#   Text(1.0977399370668657, -0.07047716345337644, 'Others')],
#  [Text(0.580376918623124, 0.15219274729607737, '8.2%'),
#   Text(-0.45686757836570724, 0.3889370332563541, '61.2%'),
#   Text(-0.025641231119075954, -0.7995889739526791, '10.2%'),
#   Text(0.2944305624187183, -0.5227912048933084, '7.1%'),
#   Text(0.4568676011250271, -0.38893700652195995, '4.1%'),
#   Text(0.7841868616116581, -0.44164574726318606, '2.0%'),
#   Text(0.5752007233204278, -0.17071651323658368, '5.1%'),
# ...

# %%
#plt.pie(bahadur,explode=[0,0.1,0,0,0,0,0,0],labels=['cloth','Food waste','Plastic','Paper','Glass','Metal','Wood','Others'],autopct='%2.1f%%')

# %%
plt.pie(bahadur,explode=[0,0,0.2,0,0,0.3,0,0],labels=['cloth','Food waste','Plastic','Paper','Glass','Metal','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5867b76150>,
# ...
#  [Text(1.07971507228839, 0.2102744936345753, 'cloth'),
#   Text(-0.5702317568418743, 0.940657080709559, 'Food waste'),
#   Text(-0.4878472801772675, -1.204991714172194, 'Plastic'),
#   Text(0.4127935660697949, -1.0196084894759272, 'Paper'),
#   Text(0.8143057019312598, -0.7395310837295742, 'Glass'),
#   Text(1.261356338895013, -0.6074373929298138, 'Metal'),
#   Text(1.0724206722979408, -0.24477316361895732, 'Wood'),
#   Text(1.097739923044929, -0.07047738185626393, 'Others')],
#  [Text(0.5889354939754854, 0.11469517834613197, '6.1%'),
#   Text(-0.31103550373193145, 0.5130856803870321, '55.1%'),
#   Text(-0.3002137108783184, -0.741533362567504, '15.3%'),
#   Text(0.2251601269471608, -0.5561500851686875, '9.2%'),
#   Text(0.44416674650795984, -0.40338059112522223, '5.1%'),
#   Text(0.810871932146794, -0.39049546688345166, '4.1%'),
#   Text(0.5849567303443313, -0.13351263470124944, '3.1%'),
# ...

# %%
ram=[12,5,8,6,58,5,4,3]


plt.pie(ram,explode=[0.2,0,0,0,0,0.3,0,0],labels=['Plastic','cloth','Paper','Glass','Food waste','Metal','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5867856e50>,
# ...
#  [Text(1.2104872779804547, 0.4740469911806942, 'Plastic'),
#   Text(0.6820104918062196, 0.8630536999898897, 'cloth'),
#   Text(0.2874541064296991, 1.0617768770776201, 'Paper'),
#   Text(-0.1872679194587346, 1.0839422154070746, 'Glass'),
#   Text(-0.9134267598772913, -0.6129041967062009, 'Food waste'),
#   Text(1.1625432219692065, -0.7800597778718351, 'Metal'),
#   Text(1.036237712333119, -0.3690682911584582, 'Wood'),
#   Text(1.091496867856544, -0.13650856185365912, 'Others')],
#  [Text(0.7449152479879722, 0.29172122534196565, '11.9%'),
#   Text(0.3720057228033925, 0.47075656363084883, '5.0%'),
#   Text(0.15679314896165406, 0.57915102386052, '7.9%'),
#   Text(-0.1021461378865825, 0.5912412084038589, '5.9%'),
#   Text(-0.4982327781148861, -0.3343113800215641, '57.4%'),
#   Text(0.7473492141230612, -0.5014670000604653, '5.0%'),
#   Text(0.5652205703635194, -0.2013099769955226, '3.0%'),
# ...

# %%
cha=[12,6,8,4,5,59,3,2]


plt.pie(cha,explode=[0.2,0,0,0,0.2,0,0,0],labels=['Plastic','cloth','Paper','Glass','Metal','Food waste','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5867495350>,
# ...
#  [Text(1.206878307437644, 0.483161206054923, 'Plastic'),
#   Text(0.6380625751062828, 0.8960335653583181, 'cloth'),
#   Text(0.19101295880800395, 1.083288534771513, 'Paper'),
#   Text(-0.22528737089214576, 1.0766826832992649, 'Glass'),
#   Text(-0.6139524318827597, 1.1458893539016957, 'Metal'),
#   Text(-0.6380625541331034, -0.8960335802932504, 'Food waste'),
#   Text(1.0729727847684774, -0.24234150108097258, 'Wood'),
#   Text(1.0977853498386874, -0.06976622162301145, 'Others')],
#  [Text(0.7426943430385501, 0.2973299729568757, '12.1%'),
#   Text(0.34803413187615423, 0.4887455811045371, '6.1%'),
#   Text(0.10418888662254759, 0.5908846553299162, '8.1%'),
#   Text(-0.12288402048662495, 0.5872814636177808, '4.0%'),
#   Text(-0.37781688115862133, 0.7051626793241204, '5.1%'),
#   Text(-0.34803412043623816, -0.48874558925086375, '59.6%'),
#   Text(0.5852578826009875, -0.13218627331689412, '3.0%'),
# ...

# %%
new=[12,10,7,3,64,6,1,3]


plt.pie(new,explode=[0,0.2,0,0,0,0.2,0,0],labels=['Paper','Plastic','cloth','Glass','Food waste','Metal','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5867638290>,
# ...
#  [Text(1.03116162521766, 0.3830218044426114, 'Paper'),
#   Text(0.693970374847944, 1.0992748149727638, 'Plastic'),
#   Text(0.06516466595083878, 1.098068106408485, 'cloth'),
#   Text(-0.2583746791637678, 1.0692251985278967, 'Glass'),
#   Text(-0.8743398478224593, -0.667480209826328, 'Food waste'),
#   Text(1.1896893482417876, -0.5240603540433403, 'Metal'),
#   Text(1.0764121620426212, -0.22657638316190357, 'Wood'),
#   Text(1.095654835892362, -0.09767538372426052, 'Others')],
#  [Text(0.5624517955732691, 0.20892098424142438, '11.3%'),
#   Text(0.4270586922141193, 0.6764768092140085, '9.4%'),
#   Text(0.03554436324591206, 0.5989462398591735, '6.6%'),
#   Text(-0.14093164318023696, 0.5832137446515799, '2.8%'),
#   Text(-0.4769126442667959, -0.36408011445072436, '60.4%'),
#   Text(0.7321165219949461, -0.3224986794112863, '5.7%'),
#   Text(0.5871339065687025, -0.12358711808831102, '0.9%'),
# ...

# %%
medical=[40,7,20,11,4,12,5]

plt.pie(medical,explode=[0,0.2,0,0,0,0.2,0],labels=['bandage','Glass','cloth','Globes','Musk','Plastic','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5867410d50>,
# ...
#  [Text(0.32661243868904005, 1.050392457557459, 'bandage'),
#   Text(-1.206878284819234, 0.4831612625529738, 'Glass'),
#   Text(-0.9777190335625252, -0.5040490962292876, 'cloth'),
#   Text(-0.12192211733500562, -1.0932223000399093, 'Globes'),
#   Text(0.3925747547106613, -1.0275626803090234, 'Musk'),
#   Text(0.9958577130306157, -0.8356239677016405, 'Plastic'),
#   Text(1.0861827658738732, -0.1738016085040154, 'Others')],
#  [Text(0.1781522392849309, 0.5729413404858866, '40.4%'),
#   Text(-0.7426943291195287, 0.2973300077249069, '7.1%'),
#   Text(-0.5333012910341046, -0.2749358706705205, '20.2%'),
#   Text(-0.06650297309182124, -0.5963030727490414, '11.1%'),
#   Text(0.2141316843876334, -0.5604887347140127, '4.0%'),
#   Text(0.612835515711148, -0.5142301339702403, '12.1%'),
#   Text(0.5924633268402943, -0.09480087736582657, '5.1%')])

# %%
#######################

# %%
abdur_rahim_medi=[44,8,13,9,6,11,15,4]

plt.pie(abdur_rahim_medi,explode=[0,0.2,0,0,0,0.2,0,0],labels=['Bandage','Cloth','Globes','Glass','Musk','Plastic','Pharmaceuticals materials','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbe6f13fc50>,
# ...
#  [Text(0.33991867422268784, 1.0461621742897658, 'Bandage'),
#   Text(-1.1974607643400992, 0.5060511020302451, 'Cloth'),
#   Text(-1.078090812832188, -0.21844953487437838, 'Globes'),
#   Text(-0.7437923854729137, -0.8104152560956097, 'Glass'),
#   Text(-0.33991869870988106, -1.0461621663333946, 'Musk'),
#   Text(0.22167885096755666, -1.2809599865076597, 'Plastic'),
#   Text(0.8710924825208282, -0.671712652028902, 'Pharmaceuticals materials'),
#   Text(1.09282991227197, -0.12539052134686512, 'Others')],
#  [Text(0.1854101859396479, 0.5706339132489631, '40.0%'),
#   Text(-0.7368989319015995, 0.3114160627878431, '7.3%'),
#   Text(-0.5880495342721025, -0.11915429174966091, '11.8%'),
#   Text(-0.4057049375306802, -0.4420446851430598, '8.2%'),
#   Text(-0.18541019929629876, -0.5706339089091242, '5.5%'),
#   Text(0.1364177544415733, -0.7882830686200983, '10.0%'),
#   Text(0.4751413541022699, -0.366388719288492, '13.6%'),
# ...

# %%
sadar_medi=[38,12,15,7,4,9,12,2]

plt.pie(sadar_medi,explode=[0,0.2,0,0,0,0.2,0,0],labels=['Bandage','Cloth','Globes','Glass','Musk','Plastic','Pharmaceuticals materials','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc5ca7da490>,
# ...
#  [Text(0.39257483889210154, 1.0275626481479563, 'Bandage'),
#   Text(-1.221600416272549, 0.4446261609068175, 'Cloth'),
#   Text(-0.961234289993094, -0.5348164542546092, 'Globes'),
#   Text(-0.39257479078842206, -1.0275626665257098, 'Glass'),
#   Text(-0.017452513540824013, -1.099861541181938, 'Musk'),
#   Text(0.5022487243525635, -1.1990605568052946, 'Plastic'),
#   Text(0.9612343525844999, -0.5348163417580445, 'Pharmaceuticals materials'),
#   Text(1.0977853498386874, -0.06976622162301145, 'Others')],
#  [Text(0.21413173030478264, 0.5604887171716125, '38.4%'),
#   Text(-0.7517541023215686, 0.27361609901958, '12.1%'),
#   Text(-0.5243096127235057, -0.29171806595705957, '15.2%'),
#   Text(-0.214131704066412, -0.5604887271958416, '7.1%'),
#   Text(-0.00951955284044946, -0.5999244770083296, '4.0%'),
#   Text(0.309076138063116, -0.7378834195724888, '9.1%'),
#   Text(0.5243096468642726, -0.29171800459529695, '12.1%'),
# ...

# %%
islamic_medi=[42,7,12,5,3,10,16,3]

plt.pie(islamic_medi,explode=[0,0.2,0,0,0,0.2,0,0],labels=['Bandage','Cloth','Globes','Glass','Musk','Plastic','Pharmaceuticals materials','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbe6f039e50>,
# ...
#  [Text(0.2447730130080499, 1.0724207066739067, 'Bandage'),
#   Text(-1.2674062964765471, 0.28927716752554655, 'Cloth'),
#   Text(-1.0196084121788636, -0.41279375699506027, 'Globes'),
#   Text(-0.6579215306913044, -0.8815550234970084, 'Glass'),
#   Text(-0.41279363766677174, -1.0196084604895324, 'Musk'),
#   Text(0.04166715263380886, -1.299332077796662, 'Plastic'),
#   Text(0.8375906104076336, -0.7130511688209815, 'Pharmaceuticals materials'),
#   Text(1.0949170315602215, -0.10562525265935838, 'Others')],
#  [Text(0.1335125525498454, 0.5849567490948581, '42.9%'),
#   Text(-0.7799423362932596, 0.1780167184772594, '7.1%'),
#   Text(-0.5561500430066528, -0.22516023108821467, '12.2%'),
#   Text(-0.3588662894679842, -0.48084819463473183, '5.1%'),
#   Text(-0.22516016600005728, -0.5561500693579267, '3.1%'),
#   Text(0.02564132469772852, -0.799588970951792, '10.2%'),
#   Text(0.456867605676891, -0.3889370011750808, '16.3%'),
# ...

# %%
zia_medi=[36,13,10,7,5,12,17,4]

plt.pie(zia_medi,explode=[0,0.2,0,0,0,0.2,0,0],labels=['Bandage','Cloth','Globes','Glass','Musk','Plastic','Pharmaceuticals materials','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbe6efb0bd0>,
# ...
#  [Text(0.5111954611888796, 0.9740016429451692, 'Bandage'),
#   Text(-1.0916954288632574, 0.7058336139622914, 'Cloth'),
#   Text(-1.0919797531522775, -0.13259041709524583, 'Globes'),
#   Text(-0.8859961941585477, -0.6519284806913787, 'Glass'),
#   Text(-0.5972437947662386, -0.9237423069304682, 'Musk'),
#   Text(-0.07849192048345269, -1.2976282281219145, 'Plastic'),
#   Text(0.8009551184976113, -0.7539700910198479, 'Pharmaceuticals materials'),
#   Text(1.0919797733250323, -0.13259025095764443, 'Others')],
#  [Text(0.278833887921207, 0.5312736234246377, '34.6%'),
#   Text(-0.6718125716081582, 0.43435914705371775, '12.5%'),
#   Text(-0.5956253199012422, -0.07232204568831589, '9.6%'),
#   Text(-0.48327065135920777, -0.3555973531043883, '6.7%'),
#   Text(-0.3257693425997664, -0.5038594401438917, '4.8%'),
#   Text(-0.048302720297509344, -0.7985404480750242, '11.5%'),
#   Text(0.4368846100896061, -0.41125641328355333, '16.3%'),
# ...

# %%
lili=[8,14,10,6,48,5,3,2]


plt.pie(lili,explode=[0.2,0,0,0,0,0.3,0,0],labels=['Plastic','cloth','Paper','Glass','Food waste','Metal','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbe6ef6a3d0>,
# ...
#  [Text(1.2557035715506135, 0.3364647684305647, 'Plastic'),
#   Text(0.6111272563215626, 0.9146165735327998, 'cloth'),
#   Text(-0.21459932896511108, 1.0788638134666138, 'Paper'),
#   Text(-0.725280370799557, 0.827023810862092, 'Glass'),
#   Text(-0.6696375991452629, -0.8726886534216934, 'Food waste'),
#   Text(1.2346897469166385, -0.6599554749063965, 'Metal'),
#   Text(1.0712646674607098, -0.24978393112907601, 'Wood'),
#   Text(1.0976448128961966, -0.07194348283252362, 'Others')],
#  [Text(0.7727406594157621, 0.20705524211111676, '8.3%'),
#   Text(0.33334213981176136, 0.4988817673815271, '14.6%'),
#   Text(-0.11705417943551512, 0.5884711709817892, '10.4%'),
#   Text(-0.3956074749815765, 0.4511038968338683, '6.2%'),
#   Text(-0.3652568722610524, -0.4760119927754691, '50.0%'),
#   Text(0.7937291230178389, -0.4242570910112549, '5.2%'),
#   Text(0.5843261822512962, -0.13624578061585962, '3.1%'),
# ...

# %%
modern=[7,9,13,10,43,12,2,3]


plt.pie(modern,explode=[0.2,0,0,0,0,0.3,0,0],labels=['Plastic','cloth','Paper','Glass','Food waste','Metal','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbe6ee8a090>,
# ...
#  [Text(1.2680587255241906, 0.28640368122977405, 'Plastic'),
#   Text(0.8197909015797102, 0.7334458928149548, 'cloth'),
#   Text(0.1565463267343023, 1.0888035854028022, 'Paper'),
#   Text(-0.6093120576939788, 0.915826848453751, 'Glass'),
#   Text(-0.8426489168532448, -0.707066335590978, 'Food waste'),
#   Text(1.0724621735582522, -0.8999027093451322, 'Metal'),
#   Text(1.0647435602851132, -0.2762628292611616, 'Wood'),
#   Text(1.0950191108625695, -0.10456168918751989, 'Others')],
#  [Text(0.7803438310918094, 0.17624841921832246, '7.1%'),
#   Text(0.4471586735889328, 0.40006139608088437, '9.1%'),
#   Text(0.0853889054914376, 0.5938928647651648, '13.1%'),
#   Text(-0.332352031469443, 0.4995419173384096, '10.1%'),
#   Text(-0.45962668191995165, -0.385672546685988, '43.4%'),
#   Text(0.6894399687160192, -0.5785088845790135, '12.1%'),
#   Text(0.5807692147009708, -0.15068881596063358, '2.0%'),
# ...

# %%
munsi=[10,16,15,7,45,4,1,3]


plt.pie(munsi,explode=[0.2,0,0,0,0,0.3,0,0],labels=['Plastic','cloth','Paper','Glass','Food waste','Metal','Wood','Others'],autopct='%2.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbe6edf6bd0>,
# ...
#  [Text(1.2376170394237203, 0.3978744321115216, 'Plastic'),
#   Text(0.4794728662881554, 0.9900029143863269, 'cloth'),
#   Text(-0.5400934770783002, 0.9582792056689281, 'Paper'),
#   Text(-1.0242584659834617, 0.4011166848452029, 'Glass'),
#   Text(-0.35290839170634175, -1.0418520370298479, 'Food waste'),
#   Text(1.3036016421560501, -0.510512251143937, 'Metal'),
#   Text(1.0740283411915499, -0.23761970102945526, 'Wood'),
#   Text(1.0952142736207557, -0.10249729195135077, 'Others')],
#  [Text(0.7616104857992124, 0.24484580437632095, '9.9%'),
#   Text(0.2615306543389938, 0.5400015896652691, '15.8%'),
#   Text(-0.2945964420427092, 0.5226977485466879, '14.9%'),
#   Text(-0.5586864359909791, 0.2187909190064743, '6.9%'),
#   Text(-0.1924954863852773, -0.5682829292890078, '44.6%'),
#   Text(0.8380296271003177, -0.32818644716395945, '4.0%'),
#   Text(0.5858336406499363, -0.1296107460160665, '1.0%'),
# ...
